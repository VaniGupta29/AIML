# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\user\\Desktop\\Vani_Linear_Regression\\train (1).csv")
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df.isna().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
df['Ever_Married'].mode()
# Out:
# 0    Yes
# Name: Ever_Married, dtype: object

# %%
df['Ever_Married'] = df['Ever_Married'].fillna('Yes')

# %%
df['Graduated'].mode()
# Out:
# 0    Yes
# Name: Graduated, dtype: object

# %%
df['Graduated']=df['Graduated'].fillna('Yes')

# %%
df['Profession'].mode()
# Out:
# 0    Artist
# Name: Profession, dtype: object

# %%
df['Profession']=df['Profession'].fillna('Artist')

# %%
df['Work_Experience'].mean()
# Out:
# np.float64(2.641663213150988)

# %%
df['Work_Experience'] = df['Work_Experience'].fillna(2.641)

# %%
df['Family_Size'].mean()
# Out:
# np.float64(2.85012285012285)

# %%
df['Family_Size']=df['Family_Size'].fillna(2.85)

# %%
df.drop(['Var_1'],axis=1,inplace=True)

# %%
df.drop(['ID'],axis=1,inplace=True)

# %%
df['Gender']=df['Gender'].replace({
    'Male': 1,
    'Female':0

})
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9756\1575797741.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']=df['Gender'].replace({
#       Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0          1           No   22        No     Healthcare            1.000
# 1          0          Yes   38       Yes       Engineer            2.641
# 2          0          Yes   67       Yes       Engineer            1.000
# 3          1          Yes   67       Yes         Lawyer            0.000
# 4          0          Yes   40       Yes  Entertainment            2.641
# ...      ...          ...  ...       ...            ...              ...
# 8063       1           No   22        No         Artist            0.000
# ...

# %%
print(df['Gender'].unique())
print(df['Ever_Married'].unique())
print(df['Graduated'].unique())
print(df['Profession'].unique())
print(df['Spending_Score'].unique())
print(df['Segmentation'].unique())
# Out:
# [1 0]
# ['No' 'Yes']
# ['No' 'Yes']
# ['Healthcare' 'Engineer' 'Lawyer' 'Entertainment' 'Artist' 'Executive'
#  'Doctor' 'Homemaker' 'Marketing']
# ['Low' 'Average' 'High']
# ['D' 'A' 'B' 'C']

# %%
df['Ever_Married']=df['Ever_Married'].replace({
    'Yes': 1,
    'No':0
})
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9756\3089929652.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Ever_Married']=df['Ever_Married'].replace({
#       Gender  Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0          1             0   22        No     Healthcare            1.000
# 1          0             1   38       Yes       Engineer            2.641
# 2          0             1   67       Yes       Engineer            1.000
# 3          1             1   67       Yes         Lawyer            0.000
# 4          0             1   40       Yes  Entertainment            2.641
# ...      ...           ...  ...       ...            ...              ...
# ...

# %%
df['Graduated']=df['Graduated'].replace({
    'Yes': 1,
    'No':0
})
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9756\3868754439.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Graduated']=df['Graduated'].replace({
#       Gender  Ever_Married  Age  Graduated     Profession  Work_Experience  \
# 0          1             0   22          0     Healthcare            1.000
# 1          0             1   38          1       Engineer            2.641
# 2          0             1   67          1       Engineer            1.000
# 3          1             1   67          1         Lawyer            0.000
# 4          0             1   40          1  Entertainment            2.641
# ...      ...           ...  ...        ...            ...              ...
# ...

# %%
df['Spending_Score']=df['Spending_Score'].replace({
    'Low': 0,
    'High':1,
    'Average':2
})
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9756\172731730.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Spending_Score']=df['Spending_Score'].replace({
#       Gender  Ever_Married  Age  Graduated     Profession  Work_Experience  \
# 0          1             0   22          0     Healthcare            1.000
# 1          0             1   38          1       Engineer            2.641
# 2          0             1   67          1       Engineer            1.000
# 3          1             1   67          1         Lawyer            0.000
# 4          0             1   40          1  Entertainment            2.641
# ...      ...           ...  ...        ...            ...              ...
# ...

# %%
df['Segmentation']=df['Segmentation'].replace({
    'A':0,
    'B':1,
    'C':2,
    'D':3
})
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9756\3469362623.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Segmentation']=df['Segmentation'].replace({
#       Gender  Ever_Married  Age  Graduated     Profession  Work_Experience  \
# 0          1             0   22          0     Healthcare            1.000
# 1          0             1   38          1       Engineer            2.641
# 2          0             1   67          1       Engineer            1.000
# 3          1             1   67          1         Lawyer            0.000
# 4          0             1   40          1  Entertainment            2.641
# ...      ...           ...  ...        ...            ...              ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()
df['Profession']=LE.fit_transform(df['Profession'])
df
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5            1.000
# 1          0             1   38          1           2            2.641
# 2          0             1   67          1           2            1.000
# 3          1             1   67          1           7            0.000
# 4          0             1   40          1           3            2.641
# ...      ...           ...  ...        ...         ...              ...
# 8063       1             0   22          0           0            0.000
# 8064       1             0   35          0           4            3.000
# 8065       0             0   33          1           5            1.000
# 8066       0             0   27          1           5            1.000
# 8067       1             1   37          1           4            0.000
#
#       Spending_Score  Family_Size  Segmentation
# 0                  0          4.0             3
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Segmentation'],
#       dtype='object')

# %%
X= df[['Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
       'Work_Experience', 'Spending_Score', 'Family_Size']]
y = df['Segmentation']

# %%
X
# Out:
#       Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0          1             0   22          0           5            1.000
# 1          0             1   38          1           2            2.641
# 2          0             1   67          1           2            1.000
# 3          1             1   67          1           7            0.000
# 4          0             1   40          1           3            2.641
# ...      ...           ...  ...        ...         ...              ...
# 8063       1             0   22          0           0            0.000
# 8064       1             0   35          0           4            3.000
# 8065       0             0   33          1           5            1.000
# 8066       0             0   27          1           5            1.000
# 8067       1             1   37          1           4            0.000
#
#       Spending_Score  Family_Size
# 0                  0          4.0
# ...

# %%
y
# Out:
# 0       3
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 8063    3
# 8064    3
# 8065    3
# 8066    1
# 8067    1
# Name: Segmentation, Length: 8068, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([3, 3, 0, ..., 1, 3, 3], shape=(2017,))

# %%
from sklearn.tree import plot_tree
plot_tree(model)
# Out:
# [Text(0.3607838926474894, 0.9833333333333333, 'x[2] <= 34.0\ngini = 0.748\nsamples = 6051\nvalue = [1477, 1391, 1468, 1715]'),
#  Text(0.08601809989011988, 0.95, 'x[2] <= 24.0\ngini = 0.586\nsamples = 2002\nvalue = [395, 196, 222, 1189]'),
#  Text(0.22340099626880464, 0.9666666666666666, 'True  '),
#  Text(0.01395253504761698, 0.9166666666666666, 'x[4] <= 4.5\ngini = 0.208\nsamples = 578\nvalue = [21, 18, 26, 513]'),
#  Text(0.009097177730239225, 0.8833333333333333, 'x[4] <= 0.5\ngini = 0.599\nsamples = 98\nvalue = [14, 9, 18, 57]'),
#  Text(0.004973449597671818, 0.85, 'x[5] <= 9.5\ngini = 0.227\nsamples = 16\nvalue = [1, 1, 0, 14]'),
#  Text(0.004625959669450206, 0.8166666666666667, 'x[2] <= 18.5\ngini = 0.124\nsamples = 15\nvalue = [0, 1, 0, 14]'),
#  Text(0.004278469741228594, 0.7833333333333333, 'x[6] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1]'),
#  Text(0.003930979813006982, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
# ...
