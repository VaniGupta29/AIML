# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\user\\Desktop\\Vani_Linear_Regression\\test.csv")
df
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df[['x']], df['y'], test_size=0.3, random_state=200)
print(X_train,X_test,y_train,y_test)
# Out:
#       x
# 134  28
# 215  55
# 91   38
# 56   39
# 69   13
# ..   ..
# 79   84
# 183  91
# 272  56
# 105  12
# 282  64
#
# [210 rows x 1 columns]       x
# 98   73
# 148  35
# 225  39
# 163  16
# 247  86
# ..   ..
# 154  63
# 122  98
# 232  88
# 265  20
# 94   60
#
# [90 rows x 1 columns] 134    29.317700
# 215    51.800359
# 91     38.430764
# 56     47.493748
# 69     17.076111
#          ...
# 79     83.688205
# 183    91.692407
# 272    56.014481
# 105    12.592447
# 282    67.681421
# Name: y, Length: 210, dtype: float64 98     70.349698
# 148    34.853482
# 225    38.057664
# 163    21.165239
# 247    82.870594
#          ...
# 154    61.740632
# 122    95.580172
# 232    87.369389
# 265    19.878465
# 94     60.910543
# Name: y, Length: 90, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)*100
# Out:
# 99.0311908426272

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['x'], df['y'], color='blue', label='Actual Data Points')
plt.plot(X_test, y_pred, color='red', label='Linear Regression Line')
