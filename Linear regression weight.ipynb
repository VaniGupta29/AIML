# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\user\\Desktop\\Vani_Linear_Regression\\weight_water.csv")
df = df[["Weight_kg", "Daily_Water_Intake_Liters"]]
df
# Out:
#      Weight_kg  Daily_Water_Intake_Liters
# 0         66.2                       3.04
# 1        106.6                       3.80
# 2         91.2                       3.85
# 3         81.9                       3.64
# 4         50.9                       2.70
# ..         ...                        ...
# 995       46.4                       2.00
# 996      104.2                       3.94
# 997       49.6                       2.48
# 998      106.5                       4.07
# 999       71.2                       2.93
#
# [1000 rows x 2 columns]

# %%
X = df[['Weight_kg']]
y = df['Daily_Water_Intake_Liters']

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print(model.predict([[5]]))
# Out:
# [1.22537478]
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['Weight_kg']], df['Daily_Water_Intake_Liters'], test_size=0.3, random_state=200)
print(X_train,X_test,y_train,y_test)
# Out:
#      Weight_kg
# 492       59.4
# 105       57.5
# 556       49.4
# 675      108.8
# 748      103.5
# ..         ...
# 810      108.9
# 836      104.0
# 784       52.7
# 617       59.4
# 794       41.3
#
# [700 rows x 1 columns]      Weight_kg
# 674       68.7
# 233       74.5
# 739       66.4
# 865       79.2
# 523       98.9
# ..         ...
# 203      102.9
# 116       96.3
# 434       45.9
# 598       53.5
# 5         50.9
#
# [300 rows x 1 columns] 492    2.45
# 105    3.28
# 556    2.30
# 675    3.73
# 748    3.96
#        ...
# 810    3.95
# 836    4.21
# 784    2.80
# 617    2.49
# 794    2.38
# Name: Daily_Water_Intake_Liters, Length: 700, dtype: float64 674    3.23
# 233    3.03
# 739    3.55
# 865    3.50
# 523    3.74
#        ...
# 203    4.07
# 116    3.84
# 434    2.29
# 598    2.42
# 5      2.85
# Name: Daily_Water_Intake_Liters, Length: 300, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 79.52657218731957

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Weight_kg'], df['Daily_Water_Intake_Liters'], color='blue', label='Actual Data Points')
plt.plot(X_test, y_pred, color='red', label='Linear Regression Line')
