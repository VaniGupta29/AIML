# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\user\\Desktop\\Vani_Linear_Regression\Salary_dataset.csv")
df = df[["YearsExperience", "Salary"]]
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\user\AppData\Local\Temp\ipykernel_13924\1702225338.py:1: SyntaxWarning: invalid escape sequence '\S'
#   df = pd.read_csv("C:\\Users\\user\\Desktop\\Vani_Linear_Regression\Salary_dataset.csv")
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# ...

# %%
X = df[['YearsExperience']]
y = df['Salary']

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print(model.predict([[9]]))
# Out:
# [109897.86485962]
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df[['YearsExperience']], df['Salary'], test_size=0.3, random_state=200)
print(X_train,X_test,y_train,y_test)
# Out:
#     YearsExperience
# 8               3.3
# 5               3.0
# 27              9.7
# 17              5.4
# 28             10.4
# 20              6.9
# 3               2.1
# 7               3.3
# 1               1.4
# 25              9.1
# 6               3.1
# 11              4.1
# 14              4.6
# 15              5.0
# 12              4.1
# 23              8.3
# 10              4.0
# 4               2.3
# 16              5.2
# 9               3.8
# 26              9.6     YearsExperience
# 24              8.8
# 29             10.6
# 2               1.6
# 22              8.0
# 0               1.2
# 18              6.0
# 13              4.2
# 19              6.1
# 21              7.2 8      64446.0
# 5      56643.0
# 27    112636.0
# 17     83089.0
# 28    122392.0
# 20     91739.0
# 3      43526.0
# 7      54446.0
# 1      46206.0
# 25    105583.0
# 6      60151.0
# 11     55795.0
# 14     61112.0
# 15     67939.0
# 12     56958.0
# 23    113813.0
# 10     63219.0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 96.5774163173889

# %%
import matplotlib.pyplot as plt
plt.scatter(df['YearsExperience'], df['Salary'], color='blue', label='Actual Data Points')
plt.plot(X_test, y_pred, color='red', label='Linear Regression Line')
